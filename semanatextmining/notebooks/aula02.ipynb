# %% [markdown]
# # PLN - Processamento de Linguagem Natural

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Engenherio de IA (vocês)
# - Texto  (Dados não estruturados) E EDA
# - Data mining (text-mining) - TDM
#
# - Onde minerar
# * Emails
# * Transcrições
# * Artigos
# * SMSs
# * Diário de bordo
# * Livros
#
# - Desafios:
# * Transformar texto em voz
# * Transformar voz em texto
# * Feature Engeneering: texto em dados numéricos.

# %% [markdown]
# # Natural Language Toolkit

# %% [markdown]
# - Lembra do Dataset? Corpus (texto que será minerado)
# - Conjunto de Corpus:
#
# A biblioteca NLTK - ferramentas para trabalhar com texto, além de corpora de textos em diversos idiomas.

# %% [markdown]
# - Analizar sentimentos
# - Nuvem de palavras

# %% [markdown]
# ![image.png](attachment:image.png)
