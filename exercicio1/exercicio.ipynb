# %% [markdown]
# ## Atividade
# 1) Entrar no kaggle -> saúde mental
# 2) Criar novo notebook exercicio.ipynb
# 3) Ler o dataset
# 4) Mostrar o dataset
# 5) Mostrar os 10 primeiros
# 6) Mostrar os 10 últimos
# 7) Commitar e dar push no github

# %% [markdown]
#    1) Instalar a venv
#
#     CTRL + SHIFT + P
#     CREATE ENVIRONMENT(CHOOSE PYTHON)
#     CHOOSE .VENV
#
#     no CMD/ Prompt Comandos
#
#     cd .\.venv\
#     cd .\Scripts\
#
#     activate
#
#     Verificar se o pandas instalou
#     pip show pandas
#     pip install pandas
#
#     2) importar pandas

# %%
! pip install pandas

# %%
import pandas as pd

# %% [markdown]
# 3) Ler o Dataset
# 4) Mostar o Dataset

# %%
url = "dataset/mental-illnesses-prevalence.csv"

pd.read_csv(url)
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6415     Zimbabwe  ZWE  2015
# 6416     Zimbabwe  ZWE  2016
# 6417     Zimbabwe  ZWE  2017
# 6418     Zimbabwe  ZWE  2018
# 6419     Zimbabwe  ZWE  2019
#
#       Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                              0.223206
# 1                                              0.222454
# 2                                              0.221751
# 3                                              0.220987
# 4                                              0.220183
# ...                                                 ...
# 6415                                           0.201042
# 6416                                           0.201319
# 6417                                           0.201639
# ...

# %% [markdown]
# 5) Mostrar os 10 Primeiros

# %%
url = "dataset/mental-illnesses-prevalence.csv"
dados = pd.read_csv(url,sep=",")
dados.head(10)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
# 5  Afghanistan  AFG  1995
# 6  Afghanistan  AFG  1996
# 7  Afghanistan  AFG  1997
# 8  Afghanistan  AFG  1998
# 9  Afghanistan  AFG  1999
#
#    Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           0.223206
# 1                                           0.222454
# 2                                           0.221751
# 3                                           0.220987
# 4                                           0.220183
# 5                                           0.219409
# 6                                           0.218465
# 7                                           0.217286
# 8                                           0.216074
# 9                                           0.215068
#
# ...

# %% [markdown]
# 6) Mostrar os 10 últimos

# %%
dados.tail(10)
# Out:
#         Entity Code  Year  \
# 6410  Zimbabwe  ZWE  2010
# 6411  Zimbabwe  ZWE  2011
# 6412  Zimbabwe  ZWE  2012
# 6413  Zimbabwe  ZWE  2013
# 6414  Zimbabwe  ZWE  2014
# 6415  Zimbabwe  ZWE  2015
# 6416  Zimbabwe  ZWE  2016
# 6417  Zimbabwe  ZWE  2017
# 6418  Zimbabwe  ZWE  2018
# 6419  Zimbabwe  ZWE  2019
#
#       Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 6410                                           0.200465
# 6411                                           0.200450
# 6412                                           0.200552
# 6413                                           0.200720
# 6414                                           0.200902
# 6415                                           0.201042
# 6416                                           0.201319
# 6417                                           0.201639
# 6418                                           0.201976
# 6419                                           0.202482
#
# ...

# %% [markdown]
# 7) Commitar e push no github
#
# - git add .
# - git commit -m "primeiro commit"
# - git push

# %% [markdown]
# # Quantidades de linhas e de colunas

# %%
dados.shape
# Out:
# (6420, 8)

# %% [markdown]
# # Quais as colunas da base de dados

# %%
dados.info

# %% [markdown]
# # Explorar as diferenças entre as colunas

# %%
dados.columns

# %%
dados['Entity']

# %%
dados[['Entity', 'Code']]
