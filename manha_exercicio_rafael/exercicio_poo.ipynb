# %%
print("Alo mundo")
# Out:
# Alo mundo

# %% [markdown]
# Lista de regras
#
# - A Classe é um conjunto de objetos;
# - A Classe agrupa objetos em comum;
# - A Classe possui um contrutor: __init__
# - As Características dos objetos são atributos.
# - O self acessa as caracteristicas e comportamentos da classe.
# - Os métodos de trabalho (workers -Oziel Moreira Neto): são métodos para calcular, desenvolver a lógica de programação.

# %% [markdown]
# Exercicio:
#
# - Criar uma classe Produto.
# - Com uma função para calcular o valor total do produto

# %%
class Produto: 
    def __init__(self, qtde, preco):
        self.qtde = qtde
        self.preco = preco

    def calcular_total(self):
        return self.qtde * self.preco

# %%
# Passagem de parâmetro por valor

p = Produto(qtde=10, preco=10)

print(f"O valor total de melancias é: {p.calcular_total()}")
# Out:
# O valor total de melancias é: 100

# %% [markdown]
# Desafio:
# - Analise o dataset aluguel.csv da aula passada.
# - E crie uma classe que representará o arquivo.
# - Crie três imóveis(objetos) que estão no dataset.

# %%
import pandas as pd

url = "dataset/aluguel.csv"
dados = pd.read_csv(url,sep=";")
dados.head(25)
# Out:
#                        Tipo                   Bairro  Quartos  Vagas  Suites  \
# 0                 Quitinete               Copacabana        1      0       0
# 1                      Casa          Jardim Botânico        2      0       1
# 2   Conjunto Comercial/Sala          Barra da Tijuca        0      4       0
# 3               Apartamento                   Centro        1      0       0
# 4               Apartamento             Higienópolis        1      0       0
# 5               Apartamento             Vista Alegre        3      1       0
# 6               Apartamento                 Cachambi        2      0       0
# 7        Casa de Condomínio          Barra da Tijuca        5      4       5
# 8        Casa de Condomínio                    Ramos        2      2       0
# 9   Conjunto Comercial/Sala                   Centro        0      3       0
# 10              Apartamento                   Centro        1      0       0
# ...

# %%
dados.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
class Imovel: 
    def __init__(self, tipo, bairro, quartos, vagas, suites, area, valor, condominio, iptu):
        self.tipo = tipo
        self.bairro = bairro
        self.quartos = quartos
        self.vagas = vagas
        self.suites = suites
        self.area = area
        self.valor = valor
        self.condominio = condominio
        self.iptu = iptu

    def obter_valores(self):
        return {
            'tipo': self.tipo,
            'bairro': self.bairro,
            'quartos': self.quartos,
            'vagas': self.vagas,
            'suites': self.suites,
            'area': self.area,
            'valor': self.valor,
            'condominio': self.condominio,
            'iptu': self.iptu
        }

imovel1 = Imovel("casa","Taguatinga Norte",3,2,2,150,500.000,1200, 1600)
imovel2 = Imovel("apartamento","Taguatinga sul",3,2,2,100,600.000,1500, 1800)
imovel3 = Imovel("kitnet","Taguatinga centro",2,1,1,50,300.000,1300, 1500)

print(f"Objeto 1, Tipo: {imovel1.tipo}, Bairro: {imovel1.bairro}, Quartos: {imovel1.quartos}, Vagas: {imovel1.vagas}, Suites: {imovel1.suites}, Area: {imovel1.area}m, Valor: R${imovel1.valor}, Condominio: R${imovel1.condominio}, IPTU: R${imovel1.iptu}")
print(f"Objeto 2, Tipo: {imovel2.tipo}, Bairro: {imovel2.bairro}, Quartos: {imovel2.quartos}, Vagas: {imovel2.vagas}, Suites: {imovel2.suites}, Area: {imovel2.area}m, Valor: R${imovel2.valor}, Condominio: R${imovel2.condominio}, IPTU: R${imovel2.iptu}")
print(f"Objeto 3, Tipo: {imovel3.tipo}, Bairro: {imovel3.bairro}, Quartos: {imovel3.quartos}, Vagas: {imovel3.vagas}, Suites: {imovel3.suites}, Area: {imovel3.area}m, Valor: R${imovel3.valor}, Condominio: R${imovel3.condominio}, IPTU: R${imovel3.iptu}")

print("\n")
print(imovel1.obter_valores())
print(imovel2.obter_valores())
print(imovel3.obter_valores())
# Out:
# Objeto 1, Tipo: casa, Bairro: Taguatinga Norte, Quartos: 3, Vagas: 2, Suites: 2, Area: 150m, Valor: R$500.0, Condominio: R$1200, IPTU: R$1600
# Objeto 2, Tipo: apartamento, Bairro: Taguatinga sul, Quartos: 3, Vagas: 2, Suites: 2, Area: 100m, Valor: R$600.0, Condominio: R$1500, IPTU: R$1800
# Objeto 3, Tipo: kitnet, Bairro: Taguatinga centro, Quartos: 2, Vagas: 1, Suites: 1, Area: 50m, Valor: R$300.0, Condominio: R$1300, IPTU: R$1500
#
#
# {'tipo': 'casa', 'bairro': 'Taguatinga Norte', 'quartos': 3, 'vagas': 2, 'suites': 2, 'area': 150, 'valor': 500.0, 'condominio': 1200, 'iptu': 1600}
# {'tipo': 'apartamento', 'bairro': 'Taguatinga sul', 'quartos': 3, 'vagas': 2, 'suites': 2, 'area': 100, 'valor': 600.0, 'condominio': 1500, 'iptu': 1800}
# {'tipo': 'kitnet', 'bairro': 'Taguatinga centro', 'quartos': 2, 'vagas': 1, 'suites': 1, 'area': 50, 'valor': 300.0, 'condominio': 1300, 'iptu': 1500}

# %% [markdown]
# # Criar uma calculadora orientada a objetos
