# %% [markdown]
# # Music IA Education

# %% [markdown]
# ## Coleta de Dados

# %% [markdown]
# - Quetionário via Google Forms
# - Perguntas sobre a faixa etária, professor e estilo músical

# %% [markdown]
# ## Objetivo do Experimento
# - Criar músicas com ritmos e estilos músicais adequados para uma turma específica.
# - As músicas tem objetivo de auxiliar o professor como recurso didático, sendo que as letras das canções abordarão um conteúdo ministrado pelo professor.
# - As músicas serão geradas por IA no software SUNO e disponibilizadas em forma de link.

# %%
# Importar o pandas
import pandas as pd

# %%
df = pd.read_csv('datasets/pesquisamusicalv2.csv')

# %%
df.head()
# Out:
#   Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0  21/08/2024 10:03:25                                  3
# 1  21/08/2024 10:04:39                                  5
# 2  21/08/2024 10:04:52                                  1
# 3  21/08/2024 10:04:53                                  1
# 4  21/08/2024 10:04:55                                  5
#
#    Avalie os estilos musicais [hip hop]  Avalie os estilos musicais [mpb]  \
# 0                                     1                                 1
# 1                                     3                                 5
# 2                                     5                                 1
# 3                                     5                                 4
# 4                                     4                                 3
#
#    Avalie os estilos musicais [reggae]  Avalie os estilos musicais [funk]  \
# 0                                    1                                  1
# ...

# %%
df.colums = ['data_hora','rock', 'hip-hop','mpb','reggae', 'funk', 'sertanejo', 'gospel', 'eletronica','professor','faixa_etaria']

# %%
df.head()
# Out:
#   Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0  21/08/2024 10:03:25                                  3
# 1  21/08/2024 10:04:39                                  5
# 2  21/08/2024 10:04:52                                  1
# 3  21/08/2024 10:04:53                                  1
# 4  21/08/2024 10:04:55                                  5
#
#    Avalie os estilos musicais [hip hop]  Avalie os estilos musicais [mpb]  \
# 0                                     1                                 1
# 1                                     3                                 5
# 2                                     5                                 1
# 3                                     5                                 4
# 4                                     4                                 3
#
#    Avalie os estilos musicais [reggae]  Avalie os estilos musicais [funk]  \
# 0                                    1                                  1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 11 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Carimbo de data/hora                     95 non-null     object
#  1   Avalie os estilos musicais [rock]        95 non-null     int64
#  2   Avalie os estilos musicais [hip hop]     95 non-null     int64
#  3   Avalie os estilos musicais [mpb]         95 non-null     int64
#  4   Avalie os estilos musicais [reggae]      95 non-null     int64
#  5   Avalie os estilos musicais [funk]        95 non-null     int64
#  6   Avalie os estilos musicais [sertanejo]   95 non-null     int64
#  7   Avalie os estilos musicais [gospel]      95 non-null     int64
#  8   Avalie os estilos musicais [eletrônica]  95 non-null     int64
#  9   Qual professor                           57 non-null     object
# ...

# %%
df.describe()
# Out:
#        Avalie os estilos musicais [rock]  \
# count                          95.000000
# mean                            3.263158
# std                             1.545140
# min                             1.000000
# 25%                             2.000000
# 50%                             4.000000
# 75%                             5.000000
# max                             5.000000
#
#        Avalie os estilos musicais [hip hop]  Avalie os estilos musicais [mpb]  \
# count                             95.000000                         95.000000
# mean                               3.084211                          3.242105
# std                                1.534450                          1.396925
# min                                1.000000                          1.000000
# 25%                                1.500000                          2.000000
# 50%                                3.000000                          4.000000
# ...

# %% [markdown]
# 23/08
# - Visualizar os estilos por professor
# - Criar gáfico pizza
# - Criar grafico de barra colorida, com rotulos(figura)
# - Storytelling
# - A brincadeira dos 7 erros (brinde do grupo)
# - Grafico de linhas (tudo) [segunda-feira]
